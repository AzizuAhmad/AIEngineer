# %%
import pyspark

# %%
import pandas as pd

# Baca file Excel (gantilah 'input.xlsx' dengan nama file Anda)
df = pd.read_excel("tes1.xlsx", engine="openpyxl")  # Jika formatnya .xls, gunakan engine="xlrd"

# Simpan ke CSV
df.to_csv("tes1.csv", index=False)  # index=False agar tidak menyimpan indeks

# %%
import pandas as pd

df = pd.read_csv("tes1.csv")
df.head()
# Out:
#     Name  Age  Experience
# 0   Budi   31          10
# 1   Tono   25           3
# 2  angel   20           5

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("testing").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Grm:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>testing</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# how to read csv data
dfPyspark = spark.read.csv("tes1.csv")

# %%
dfPyspark
# Out:
# DataFrame[_c0: string, _c1: string]

# %%
dfPyspark.show()
# Out:
# +-----+---+
# |  _c0|_c1|
# +-----+---+
# | Name|Age|
# | Budi| 31|
# | Tono| 25|
# |angel| 20|
# +-----+---+

# %%
# readd dataset
dfPyspark = spark.read.option("header","true").csv("tes1.csv", inferSchema = True)
dfPyspark.show()
# Out:
# +-----+---+----------+
# | Name|Age|Experience|
# +-----+---+----------+
# | Budi| 31|        10|
# | Tono| 25|         3|
# |angel| 20|         5|
# +-----+---+----------+

# %%
type(dfPyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
dfPyspark.head(3)
# Out:
# [Row(Name='Budi', Age=31, Experience=10),
#  Row(Name='Tono', Age=25, Experience=3),
#  Row(Name='angel', Age=20, Experience=5)]

# %%
# check tehe schema
dfPyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)

# %%
dfPyspark = spark.read.csv('tes1.csv',header = True, inferSchema= True)
dfPyspark.show()
# Out:
# +-----+---+----------+
# | Name|Age|Experience|
# +-----+---+----------+
# | Budi| 31|        10|
# | Tono| 25|         3|
# |angel| 20|         5|
# +-----+---+----------+

# %%
# check tehe schema
dfPyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)

# %%
type(dfPyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
dfPyspark.columns
# Out:
# ['Name', 'Age', 'Experience']

# %%
dfPyspark.head(3)
# Out:
# [Row(Name='Budi', Age=31, Experience=10),
#  Row(Name='Tono', Age=25, Experience=3),
#  Row(Name='angel', Age=20, Experience=5)]

# %%
dfPyspark.show()
# Out:
# +-----+---+----------+
# | Name|Age|Experience|
# +-----+---+----------+
# | Budi| 31|        10|
# | Tono| 25|         3|
# |angel| 20|         5|
# +-----+---+----------+

# %%
dfPyspark.select("Name").show()
# Out:
# +-----+
# | Name|
# +-----+
# | Budi|
# | Tono|
# |angel|
# +-----+

# %%
dfPyspark.select(["Name",'age']).show()
# Out:
# +-----+---+
# | Name|age|
# +-----+---+
# | Budi| 31|
# | Tono| 25|
# |angel| 20|
# +-----+---+

# %%
dfPyspark['Name']
# Out:
# Column<'Name'>

# %%
dfPyspark.dtypes
# Out:
# [('Name', 'string'), ('Age', 'int'), ('Experience', 'int')]

# %%
dfPyspark.describe().show()
# Out:
# +-------+-----+------------------+-----------------+
# |summary| Name|               Age|       Experience|
# +-------+-----+------------------+-----------------+
# |  count|    3|                 3|                3|
# |   mean| NULL|25.333333333333332|              6.0|
# | stddev| NULL| 5.507570547286102|3.605551275463989|
# |    min| Budi|                20|                3|
# |    max|angel|                31|               10|
# +-------+-----+------------------+-----------------+

# %%
# addding columns in dataframe
dfPyspark = dfPyspark.withColumn("Experience after 2 years",dfPyspark['Experience']+2)

# %%
dfPyspark.show()
# Out:
# +-----+---+----------+------------------------+
# | Name|Age|Experience|Experience after 2 years|
# +-----+---+----------+------------------------+
# | Budi| 31|        10|                      12|
# | Tono| 25|         3|                       5|
# |angel| 20|         5|                       7|
# +-----+---+----------+------------------------+

# %%
# drop the colums

dfPyspark = dfPyspark.drop("Experience after 2 years")

# %%
dfPyspark.show()
# Out:
# +-----+---+----------+
# | Name|Age|Experience|
# +-----+---+----------+
# | Budi| 31|        10|
# | Tono| 25|         3|
# |angel| 20|         5|
# +-----+---+----------+

# %%
# rename columns
dfPyspark.withColumnRenamed("Name",'New Name').show()
# Out:
# +--------+---+----------+
# |New Name|Age|Experience|
# +--------+---+----------+
# |    Budi| 31|        10|
# |    Tono| 25|         3|
# |   angel| 20|         5|
# +--------+---+----------+

# %% [markdown]
# # HANDLING MISSING VALUES

# %%
dfPyspark = spark.read.csv("test2.csv", header= True,inferSchema=True)
dfPyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
# drop columns
dfPyspark.drop('Name').show()
# Out:
# +----+----------+------+
# | age|Experience|Salary|
# +----+----------+------+
# |  31|        10| 30000|
# |  30|         8| 25000|
# |  29|         4| 20000|
# |  24|         3| 20000|
# |  21|         1| 15000|
# |  23|         2| 18000|
# |NULL|      NULL| 40000|
# |  34|        10| 38000|
# |  36|      NULL|  NULL|
# +----+----------+------+

# %%
dfPyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
#  drop all null value
dfPyspark.na.drop().show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
# any == how

dfPyspark.na.drop(how="all").show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
# threshold
dfPyspark.na.drop(how="all",thresh=2).show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# +---------+----+----------+------+

# %%
# subset
dfPyspark.na.drop(how="any",subset=['Age']).show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# |     NULL| 34|        10| 38000|
# |     NULL| 36|      NULL|  NULL|
# +---------+---+----------+------+

# %%
# Filling missing value
dfPyspark.na.fill("Missing Values", ["Name"]).show()
# Out:
# +--------------+----+----------+------+
# |          Name| age|Experience|Salary|
# +--------------+----+----------+------+
# |         Krish|  31|        10| 30000|
# |     Sudhanshu|  30|         8| 25000|
# |         Sunny|  29|         4| 20000|
# |          Paul|  24|         3| 20000|
# |        Harsha|  21|         1| 15000|
# |       Shubham|  23|         2| 18000|
# |        Mahesh|NULL|      NULL| 40000|
# |Missing Values|  34|        10| 38000|
# |Missing Values|  36|      NULL|  NULL|
# +--------------+----+----------+------+

# %%
dfPyspark.na.fill(30, ["Age"]).show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# |   Mahesh| 30|      NULL| 40000|
# |     NULL| 34|        10| 38000|
# |     NULL| 36|      NULL|  NULL|
# +---------+---+----------+------+

# %%
dfPyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
from pyspark.ml.feature import Imputer

imputer = Imputer(
    inputCols=["age", "Experience","Salary"],
    outputCols=["{}_imputed".format(c) for c in ["age", "Experience","Salary"]]
).setStrategy("mean")

# %%
imputer.fit(dfPyspark).transform(dfPyspark).show()
# Out:
# +---------+----+----------+------+-----------+------------------+--------------+
# |     Name| age|Experience|Salary|age_imputed|Experience_imputed|Salary_imputed|
# +---------+----+----------+------+-----------+------------------+--------------+
# |    Krish|  31|        10| 30000|         31|                10|         30000|
# |Sudhanshu|  30|         8| 25000|         30|                 8|         25000|
# |    Sunny|  29|         4| 20000|         29|                 4|         20000|
# |     Paul|  24|         3| 20000|         24|                 3|         20000|
# |   Harsha|  21|         1| 15000|         21|                 1|         15000|
# |  Shubham|  23|         2| 18000|         23|                 2|         18000|
# |   Mahesh|NULL|      NULL| 40000|         28|                 5|         40000|
# |     NULL|  34|        10| 38000|         34|                10|         38000|
# |     NULL|  36|      NULL|  NULL|         36|                 5|         25750|
# ...
